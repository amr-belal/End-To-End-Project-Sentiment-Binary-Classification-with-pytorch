# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from fastapi import FastAPI
from pydantic import BaseModel
import uvicorn
import re
from typing import List
from datasets import load_dataset
import re

# %%
dataset = load_dataset("imdb")

df = pd.DataFrame(dataset['train'])

df.head()
# Out:
#                                                 text  label
# 0  I rented I AM CURIOUS-YELLOW from my video sto...      0
# 1  "I Am Curious: Yellow" is a risible and preten...      0
# 2  If only to avoid making this type of film in t...      0
# 3  This film was probably inspired by Godard's Ma...      0
# 4  Oh, brother...after hearing about this ridicul...      0

# %%
df["label"].value_counts()
# Out:
# label
# 0    12500
# 1    12500
# Name: count, dtype: int64

# %%
df_test = pd.DataFrame(dataset['test'])

df_test.head()
# Out:
#                                                 text  label
# 0  I love sci-fi and am willing to put up with a ...      0
# 1  Worth the entertainment value of a rental, esp...      0
# 2  its a totally average film with a few semi-alr...      0
# 3  STAR RATING: ***** Saturday Night **** Friday ...      0
# 4  First off let me say, If you haven't enjoyed a...      0

# %%
# clean text 

def clean_text(text):
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    
    return text.lower()

# %%
df["text"] = df["text"].apply(clean_text)

# %%
# build vocabulary
from collections import Counter
from nltk.tokenize import word_tokenize


all_tokens = [ word_tokenize(text) for text in df["text"]]

tokens_flat = [token for sublist in all_tokens for token in sublist ]

vocab = Counter(tokens_flat)


vocab = {word: i+2 for i, (word, freq) in enumerate(vocab.items()) if freq > 5}  # remove rare words
vocab['<PAD>'] = 0
vocab['<UNK>'] = 1

# %%
print(all_tokens[10])
# Out:
# ['it', 'was', 'great', 'to', 'see', 'some', 'of', 'my', 'favorite', 'stars', 'of', '30', 'years', 'ago', 'including', 'john', 'ritter', 'ben', 'gazarra', 'and', 'audrey', 'hepburn', 'they', 'looked', 'quite', 'wonderful', 'but', 'that', 'was', 'it', 'they', 'were', 'not', 'given', 'any', 'characters', 'or', 'good', 'lines', 'to', 'work', 'with', 'i', 'neither', 'understood', 'or', 'cared', 'what', 'the', 'characters', 'were', 'doingbr', 'br', 'some', 'of', 'the', 'smaller', 'female', 'roles', 'were', 'fine', 'patty', 'henson', 'and', 'colleen', 'camp', 'were', 'quite', 'competent', 'and', 'confident', 'in', 'their', 'small', 'sidekick', 'parts', 'they', 'showed', 'some', 'talent', 'and', 'it', 'is', 'sad', 'they', 'didnt', 'go', 'on', 'to', 'star', 'in', 'more', 'and', 'better', 'films', 'sadly', 'i', 'didnt', 'think', 'dorothy', 'stratten', 'got', 'a', 'chance', 'to', 'act', 'in', 'this', 'her', 'only', 'important', 'film', 'rolebr', 'br', 'the', 'film', 'appears', 'to', 'have', 'some', 'fans', 'and', 'i', 'was', 'very', 'openminded', 'when', 'i', 'started', 'watching', 'it', 'i', 'am', 'a', 'big', 'peter', 'bogdanovich', 'fan', 'and', 'i', 'enjoyed', 'his', 'last', 'movie', 'cats', 'meow', 'and', 'all', 'his', 'early', 'ones', 'from', 'targets', 'to', 'nickleodeon', 'so', 'it', 'really', 'surprised', 'me', 'that', 'i', 'was', 'barely', 'able', 'to', 'keep', 'awake', 'watching', 'this', 'onebr', 'br', 'it', 'is', 'ironic', 'that', 'this', 'movie', 'is', 'about', 'a', 'detective', 'agency', 'where', 'the', 'detectives', 'and', 'clients', 'get', 'romantically', 'involved', 'with', 'each', 'other', 'five', 'years', 'later', 'bogdanovichs', 'exgirlfriend', 'cybil', 'shepherd', 'had', 'a', 'hit', 'television', 'series', 'called', 'moonlighting', 'stealing', 'the', 'story', 'idea', 'from', 'bogdanovich', 'of', 'course', 'there', 'was', 'a', 'great', 'difference', 'in', 'that', 'the', 'series', 'relied', 'on', 'tons', 'of', 'witty', 'dialogue', 'while', 'this', 'tries', 'to', 'make', 'do', 'with', 'slapstick', 'and', 'a', 'few', 'screwball', 'linesbr', 'br', 'bottom', 'line', 'it', 'aint', 'no', 'paper', 'moon', 'and', 'only', 'a', 'very', 'pale', 'version', 'of', 'whats', 'up', 'doc']

# %%
print(vocab)
# Out:
# {'i': 2, 'rented': 3, 'am': 4, 'from': 6, 'my': 7, 'video': 8, 'store': 9, 'because': 10, 'of': 11, 'all': 12, 'the': 13, 'controversy': 14, 'that': 15, 'surrounded': 16, 'it': 17, 'when': 18, 'was': 19, 'first': 20, 'released': 21, 'in': 22, '1967': 23, 'also': 24, 'heard': 25, 'at': 26, 'seized': 27, 'by': 28, 'us': 29, 'customs': 30, 'if': 31, 'ever': 32, 'tried': 33, 'to': 34, 'enter': 35, 'this': 36, 'country': 37, 'therefore': 38, 'being': 39, 'a': 40, 'fan': 41, 'films': 42, 'considered': 43, 'controversial': 44, 'really': 45, 'had': 46, 'see': 47, 'for': 48, 'myselfbr': 49, 'br': 50, 'plot': 51, 'is': 52, 'centered': 53, 'around': 54, 'young': 55, 'swedish': 56, 'drama': 57, 'student': 58, 'named': 59, 'lena': 60, 'who': 61, 'wants': 62, 'learn': 63, 'everything': 64, 'she': 65, 'can': 66, 'about': 67, 'life': 68, 'particular': 69, 'focus': 70, 'her': 71, 'attentions': 72, 'making': 73, 'some': 74, 'sort': 75, 'documentary': 76, 'on': 77, 'what': 78, 'average': 79, 'thought': 81, 'certain': 82, 'political': 83, 'issues': 84, 'such': 85, 'as': 86, 'vietnam': 87, 'war': 88, 'and': 89, 'race': 90, 'united': 91, 'states': 92, 'between': 93, 'asking': 94, 'politicians': 95, 'ordinary': 96, 'denizens': 97, 'stockholm': 98, 'their': 99, 'opinions': 100, 'politics': 101, 'has': 102, 'sex': 103, 'with': 104, 'teacher': 105, 'classmates': 106, 'married': 107, 'menbr': 108, 'kills': 109, 'me': 110, '40': 111, 'years': 112, 'ago': 113, 'pornographic': 114, 'nudity': 115, 'scenes': 116, 'are': 117, 'few': 118, 'far': 119, 'even': 120, 'then': 121, 'its': 122, 'not': 123, 'shot': 124, 'like': 125, 'cheaply': 126, 'made': 127, 'porno': 128, 'while': 129, 'countrymen': 130, 'mind': 131, 'find': 132, 'shocking': 133, 'reality': 134, 'major': 135, 'staple': 136, 'cinema': 137, 'ingmar': 138, 'bergman': 139, 'arguably': 140, 'answer': 141, 'good': 142, 'old': 143, 'boy': 144, 'john': 145, 'ford': 146, 'his': 147, 'filmsbr': 148, 'do': 149, 'commend': 150, 'filmmakers': 151, 'fact': 152, 'any': 153, 'shown': 154, 'film': 155, 'artistic': 156, 'purposes': 157, 'rather': 158, 'than': 159, 'just': 160, 'shock': 161, 'people': 162, 'make': 163, 'money': 164, 'be': 165, 'theaters': 166, 'america': 167, 'anyone': 168, 'wanting': 169, 'study': 170, 'meat': 171, 'potatoes': 172, 'no': 173, 'pun': 174, 'intended': 175, 'but': 176, 'doesnt': 177, 'have': 178, 'much': 179, 'curious': 180, 'yellow': 181, 'risible': 182, 'pretentious': 183, 'steaming': 184, 'pile': 185, 'matter': 186, 'ones': 187, 'views': 188, 'hardly': 189, 'taken': 190, 'seriously': 191, 'level': 192, 'claim': 193, 'frontal': 194, 'male': 195, 'an': 196, 'automatic': 197, 'nc17': 198, 'isnt': 199, 'true': 200, 'ive': 201, 'seen': 202, 'rrated': 203, 'granted': 204, 'they': 205, 'only': 206, 'offer': 207, 'fleeting': 208, 'where': 209, 'gaping': 210, 'flapping': 212, 'nowhere': 214, 'dont': 215, 'exist': 216, 'same': 217, 'goes': 218, 'those': 219, 'crappy': 220, 'cable': 221, 'shows': 222, 'swinging': 224, 'breeze': 225, 'sight': 227, 'indie': 228, 'movies': 229, 'brown': 230, 'bunny': 231, 'which': 232, 'were': 233, 'treated': 234, 'site': 235, 'vincent': 236, 'throbbing': 238, 'johnson': 239, 'trace': 240, 'pink': 241, 'visible': 242, 'chloe': 243, 'sevigny': 244, 'before': 245, 'crying': 246, 'or': 247, 'implying': 248, 'matters': 250, 'mentally': 251, 'obtuse': 252, 'should': 253, 'take': 254, 'into': 255, 'account': 256, 'one': 257, 'unavoidably': 258, 'obvious': 259, 'difference': 261, 'men': 262, 'women': 263, 'there': 264, 'genitals': 265, 'display': 266, 'actresses': 267, 'appears': 268, 'nude': 269, 'said': 270, 'man': 271, 'you': 272, 'generally': 273, 'wont': 274, 'female': 275, 'american': 276, 'anything': 277, 'short': 278, 'porn': 279, 'explicit': 280, 'erotica': 281, 'alleged': 282, 'less': 283, 'double': 284, 'standard': 285, 'admittedly': 286, 'depressing': 287, 'ability': 288, 'come': 289, 'terms': 290, 'culturally': 291, 'insides': 292, 'womens': 293, 'bodies':  ...

# %%
# encode tokens

def encode(text, vocab, max_len=100):
    tokens = word_tokenize(text)
    ids = [vocab.get(token, vocab["<UNK>"]) for token in tokens[:max_len]]
    # Ensure all ids are valid indices for embedding
    vocab_size = len(vocab)
    ids = [id if id < vocab_size else vocab["<UNK>"] for id in ids]
    if len(ids) < max_len:
        ids += [vocab['<PAD>']] * (max_len - len(ids))
    return ids

# %%
df["text"]
# Out:
# 0        i rented i am curiousyellow from my video stor...
# 1        i am curious yellow is a risible and pretentio...
# 2        if only to avoid making this type of film in t...
# 3        this film was probably inspired by godards mas...
# 4        oh brotherafter hearing about this ridiculous ...
#                                ...
# 24995    a hit at the time but now better categorised a...
# 24996    i love this movie like no other another time i...
# 24997    this film and its sequel barry mckenzie holds ...
# 24998    the adventures of barry mckenzie started life ...
# 24999    the story centers around barry mckenzie who mu...
# Name: text, Length: 25000, dtype: object

# %%
df['input_ids'] = df['text'].apply(lambda x: encode(x, vocab))

# %%
df
# Out:
#                                                     text  ...                                          input_ids
# 0      i rented i am curiousyellow from my video stor...  ...  [2, 3, 2, 4, 1, 6, 7, 8, 9, 10, 11, 12, 13, 14...
# 1      i am curious yellow is a risible and pretentio...  ...  [2, 4, 180, 181, 52, 40, 182, 89, 183, 184, 18...
# 2      if only to avoid making this type of film in t...  ...  [31, 206, 34, 295, 73, 36, 296, 11, 155, 22, 1...
# 3      this film was probably inspired by godards mas...  ...  [36, 155, 19, 337, 338, 28, 339, 1, 1, 89, 2, ...
# 4      oh brotherafter hearing about this ridiculous ...  ...  [385, 1, 387, 67, 36, 388, 155, 48, 389, 112, ...
# ...                                                  ...  ...                                                ...
# 24995  a hit at the time but now better categorised a...  ...  [40, 398, 26, 13, 331, 176, 414, 329, 1, 86, 1...
# 24996  i love this movie like no other another time i...  ...  [2, 620, 36, 382, 125, 173, 576, 1193, 331, 2,...
# 24997  this film and its sequel barry mckenzie holds ...  ...  [36, 155, 89, 122, 4991, 11441, 1, 8020, 147, ...
# 24998  the adventures of barry mckenzie started life ...  ...  [13, 9063, 11, 11441, 1, 945, 68, 86, 40, 3384...
# 24999  the story centers around barry mckenzie who mu...  ...  [13, 651, 11316, 54, 11441, 1, 61, 502, 570, 3...
#
# [25000 rows x 3 columns]

# %%
class IMBDDataset(Dataset):
    def __init__(self , inputs , labels):
        self.inputs =inputs
        self.labels =  labels 
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
         
        return {
            'input_ids': torch.tensor(self.inputs[idx], dtype=torch.long),
            'label': torch.tensor(self.labels[idx], dtype=torch.long)
        }

# %%
train_texts, test_texts, train_labels, test_labels = train_test_split(df['input_ids'].tolist(), df['label'].tolist(), test_size=0.2)

train_dataset = IMBDDataset(train_texts, train_labels)
test_dataset = IMBDDataset(test_texts, test_labels)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32)

# %%
# model 

class SentimentLSTM(nn.Module):
    def __init__(self , vocab_size , embedding_dim  , hidden_dim, output_dim):
        super().__init__()
        
        self.embeddings = nn.Embedding(vocab_size, embedding_dim , padding_idx=0)
        
        self.lstm = nn.LSTM(embedding_dim, hidden_dim)
        
        self.fc = nn.Linear(hidden_dim, output_dim)
        
    
    def forward(self , x ):
        x =self.embeddings(x)
        x = x.permute(1 , 0 , 2)
        _ , (hidden ,_) =  self.lstm(x)
        x = self.fc(hidden[-1])
        return x

# %%
model = SentimentLSTM(len(vocab) , embedding_dim=100 , hidden_dim= 128 , output_dim=2 )

# %%
# training 

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters() , lr = 0.001)

def train(model ,loader ):
    model.train()
    for batch in loader :
        inputs = batch["input_ids"]
        labels = batch["label"]
        
        outputs = model(inputs)
        loss = criterion(outputs , labels)
        
        optimizer .zero_grad()
        loss.backward()
        optimizer.step()

# %%
#evaluate 

@torch.no_grad()
def evaluate(model , loader ): 
    model.eval()
    all_preds , all_labels = [],[]
    
    for batch in loader :
        inputs = batch["input_ids"]
        labels = batch["label"]
        
        outputs = model(inputs)
        preds = torch.argmax(outputs, dim=1)
        all_preds.extend(preds.tolist())
        all_labels.extend(labels.tolist())
    acc = accuracy_score(all_labels, all_preds)
    return acc

# %%
for epoch in range(5):
    train(model, train_loader)
    acc = evaluate(model, test_loader)
    print(f"Epoch {epoch+1} - Test Accuracy: {acc:.4f}")
# Out:
# Epoch 1 - Test Accuracy: 0.6560
# Epoch 2 - Test Accuracy: 0.5834
# Epoch 3 - Test Accuracy: 0.7902
# Epoch 4 - Test Accuracy: 0.8110
# Epoch 5 - Test Accuracy: 0.8104

# %%
# text examples 

text = "i love this movie"
tokens = encode(text, vocab)

inputs = torch.tensor(tokens).unsqueeze(0)
outputs = model(inputs)
pred = torch.argmax(outputs, dim=1)
print(pred.item())
# Out:
# 1

# %%
# text examples 

text = " this movie is disgusting"
tokens = encode(text, vocab)

inputs = torch.tensor(tokens).unsqueeze(0)
outputs = model(inputs)
pred = torch.argmax(outputs, dim=1)
print(pred.item())
# Out:
# 0

# %% [markdown]
# ok, sound good !!

# %%
# let's save the model 

torch.save(model.state_dict() , "model.pt")
